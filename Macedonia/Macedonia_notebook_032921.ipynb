# %% [markdown]
# #   **Jupyter Notebook**
# ##  Testing Git Repo through tempo
# ------------------
# ### Mary Kate Macedonia
# ### *03/28/2021*
# ------------------

# %%
from IPython.display import Image
Image(url='https://upload.wikimedia.org/wikipedia/commons/d/dd/Muybridge_race_horse_animated.gif')
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/d/dd/Muybridge_race_horse_animated.gif"/>

# %% [markdown]
# ## *See you in Class!*
