# %%
GIT STATUS
# Out:
#   File "<ipython-input-1-e4ec7d416476>", line 1
#     GIT STATUS
#              ^
# SyntaxError: invalid syntax

# %%
CD
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-aa3f95be06a8> in <module>
# ----> 1 CD
#
# NameError: name 'CD' is not defined

# %%
GIT STATus
# Out:
#   File "<ipython-input-3-900930818709>", line 1
#     GIT STATus
#              ^
# SyntaxError: invalid syntax

# %%
git status
# Out:
#   File "<ipython-input-4-d93c8dd246e3>", line 1
#     git status
#              ^
# SyntaxError: invalid syntax

# %%
git add .
# Out:
#   File "<ipython-input-5-3d6cfb4a5e4d>", line 1
#     git add .
#           ^
# SyntaxError: invalid syntax

# %%
git add .
# Out:
#   File "<ipython-input-6-3d6cfb4a5e4d>", line 1
#     git add .
#           ^
# SyntaxError: invalid syntax

# %%
git push .
# Out:
#   File "<ipython-input-7-1bca78f31dd5>", line 1
#     git push .
#            ^
# SyntaxError: invalid syntax

# %%
text "hello"
# Out:
#   File "<ipython-input-8-29d907a376ad>", line 1
#     text "hello"
#                ^
# SyntaxError: invalid syntax

# %%
git commit .
# Out:
#   File "<ipython-input-9-433584d7baf4>", line 1
#     git commit .
#              ^
# SyntaxError: invalid syntax

# %%
git add .
# Out:
#   File "<ipython-input-10-3d6cfb4a5e4d>", line 1
#     git add .
#           ^
# SyntaxError: invalid syntax

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f572d396fae9> in <module>
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
add test
# Out:
#   File "<ipython-input-12-a4d4f3ac5db9>", line 1
#     add test
#            ^
# SyntaxError: invalid syntax

# %%
git --help
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-776edb300136> in <module>
# ----> 1 git --help
#
# NameError: name 'git' is not defined
