# %%
#new ipynb 12:16pm
print("This is the new commit via tempo server for Jupyter")

#log in
#create folder in home directory
#clone git test-repo for class
#change cd to test-repo: cd ~/git/test-repo

#create new environment
#conda create -n test-env-L
#ipython kernel install --user --name=test-env-L
#refresh Launcher
#w/in Lindsay Martin folder, open new notebook in test-env-L
#name new notebook LM.ipynb
#add text to notebook

#git pull
#git status
#git add . 
#git commit -m "xxxxx"
#git push
#need to enter github credentials w/o ssh key


################################################3
#making SSH key:
#https://docs.github.com/en/github/authenticating-to-github/adding-a-new-ssh-key-to-your-github-account

#in tempo terminal:
# ls -al ~/.ssh
# ssh-keygen -t ed25519 -C "email"
#enter passphrase
#save in default location

#less ~/.ssh/id_ed25519.pub
#then copy ssh key + email
# paste into new ssh key entry in github account
#new key called Tempo sshkey

# eval `ssh-agent -s`
# ssh-add ~/.ssh/id_ed25519

##############
#bash
#nano .bashrc to modify bash output
#source .bashrc to check output
